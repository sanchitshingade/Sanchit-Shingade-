# %% [markdown]
# # Sanchit Shingade  |  Data Science  |  The Sparks Foundation

# %% [markdown]
# ## Task-1:
# ## Predict The Percentage Of A Student Based On The Number Of Study Hours

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("http://bit.ly/w-data")
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# ### Exploring Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# ### Plotting Data

# %%
sns.displot(x='Hours',data=df)

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x='Hours', y='Scores',data=df)
plt.xlabel("Hours")
plt.ylabel("Scores")
# Out:
# Text(336.9714285714286, 0.5, 'Scores')

# %%
plt.figure(figsize=(12,8))
sns.lmplot(x='Hours', y='Scores',data=df,palette= 'Rainbow')
plt.xlabel("Hours")
plt.ylabel("Scores")
# Out:
# Text(3.674999999999997, 0.5, 'Scores')

# %% [markdown]
# ### Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:, :-1].values  
y = df.iloc[:, 1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Linear Model

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = lm.predict(X_test)

# %% [markdown]
# ### Evaluating the model

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 4.183859899002975
# MSE: 21.5987693072174
# RMSE: 4.6474476121003665

# %% [markdown]
# ### Ploting To Explore Predicted Data

# %%
sns.distplot(y_test-pred,bins=2)
# Out:
# C:\Users\Sanchit\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
line = lm.coef_*X+lm.intercept_

# Plotting for the test data
plt.scatter(X, y)
plt.plot(X, line);
plt.show()

# %% [markdown]
# ### Predictions

# %%
hour = [9.25]

# %%
new_pred = lm.predict([hour])

# %%
results = pd.DataFrame({"Hours":hour, "Predicted Scores":new_pred})

# %% [markdown]
# ### Final Result

# %%
results

print("\nHour Studied: ",hour,"\nPredicted Score: ",new_pred)
# Out:
# Hour Studied:  [9.25]
# Predicted Score:  [93.69173249]

# %% [markdown]
# # Thank You
